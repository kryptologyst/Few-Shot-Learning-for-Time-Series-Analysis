# %% [markdown]
# # Few-Shot Time Series Learning - Interactive Analysis
#
# This notebook provides an interactive exploration of few-shot learning techniques for time series classification.
#
# ## Overview
#
# We'll explore:
# 1. Synthetic time series data generation
# 2. Multiple neural architecture embeddings
# 3. Prototypical network classification
# 4. Anomaly detection
# 5. Comprehensive visualizations

# %%
# Import required libraries
import sys
import os
sys.path.append('src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

from timeseries_analyzer import TimeSeriesAnalyzer, TimeSeriesDataGenerator
import yaml
